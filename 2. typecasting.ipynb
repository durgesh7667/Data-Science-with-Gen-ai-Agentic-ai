# %% [markdown]
# # Datatype

# %%
a=True
b=False
c=a+b
c
# Out:
# 1

# %%
type(c)
# Out:
# int

# %%
b=False

# %%
type(b)
# Out:
# bool

# %%
c=2+3j
c
# Out:
# (2+3j)

# %%
c1=3+4j
c1
# Out:
# (3+4j)

# %%
type(c1)
# Out:
# complex

# %%
c1.real
# Out:
# 3.0

# %%
c1.imag
# Out:
# 4.0

# %%
c2=c+c1
c2
# Out:
# (5+7j)

# %% [markdown]
# # String

# %%
welcome to the data science course, in this course you will study many things.
# Out:
#   Cell In[12], line 1
#     welcome to the data science course, in this course you will study many things.
#             ^
# SyntaxError: invalid syntax

# %%
'welcome to the data science course, in this course you will study many things.'
# Out:
# 'welcome to the data science course, in this course you will study many things.'

# %%
"welcome to the data science course, in this course you will study many things."
# Out:
# 'welcome to the data science course, in this course you will study many things.'

# %%
'''welcome to the data science course, in this course you will study many things.'''
# Out:
# 'welcome to the data science course, in this course you will study many things.'

# %%
# string has to be written with ''|""|'''  '''|

# %%
'welcome to the data science course,
in this course you 
will study many things.'
# Out:
#   Cell In[17], line 1
#     'welcome to the data science course,
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"welcome to the data science course,
in this course you 
will study many things."
# Out:
#   Cell In[18], line 1
#     "welcome to the data science course,
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''welcome to the data science course,
in this course you 
will study many things.'''
# Out:
# 'welcome to the data science course,\nin this course you \nwill study many things.'

# %%
s1='python'
s1
# Out:
# 'python'

# %% [markdown]
# # indexing

# %%
s2='welcometopython'
s2
# Out:
# 'welcometopython'

# %%
s2[2]                              # forward indexing
# Out:
# 'l'

# %%
s2[6]
# Out:
# 'e'

# %%
s2
# Out:
# 'welcometopython'

# %%
s2[-4]                               # backward indexing
# Out:
# 't'

# %%
len(s2)
# Out:
# 15

# %%
s2[:]
# Out:
# 'welcometopython'

# %%
s2[3:7]                       # left index apply n formula, for right index apply (n-1) formula
# Out:
# 'come'

# %%
s2[3:]                        # forward indexing 3rd to till last
# Out:
# 'cometopython'

# %%
s2[:5]                        # from start to n-1.
# Out:
# 'welco'

# %%
s2[0:20]
# Out:
# 'welcometopython'

# %%
s2[:20]
# Out:
# 'welcometopython'

# %%
s2[2:12:2]
# Out:
# 'loeoy'

# %%
s2
# Out:
# 'welcometopython'

# %%
s2[::1]
# Out:
# 'welcometopython'

# %%
s2[::2]  # slicing for two steps forwarding
# Out:
# 'wloeoyhn'

# %%
s2[::2][::3]
# Out:
# 'weh'

# %%
s2[::-1]
# Out:
# 'nohtypotemoclew'

# %%
s2[::-2]  # slicing for two steps from backward
# Out:
# 'nhyoeolw'

# %%
s2
# Out:
# 'welcometopython'

# %% [markdown]
# # typecasting to integer

# %%
int(2.3)
# Out:
# 2

# %%
int(2.3,3.4)  # only  one argument is allowed.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 int(2.3,3.4)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')  # only number string typecasting
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # other datatypes to float

# %%
float(True)
# Out:
# 1.0

# %%
float(2)
# Out:
# 2.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # other datatypes to bool

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(2.3)
# Out:
# True
