# %% [markdown]
# # Number System:-

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %%
print(0xa)
print(0xb)
print(0xc)

print(0xf)
# Out:
# 10
# 11
# 12
# 15

# %%
int(0x19)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %% [markdown]
# # Bitwise Operator:-

# %%
a=3

# %%
-a
# Out:
# -3

# %%
~a  # complement operator: -(n+1)
# Out:
# -4

# %%
~15
# Out:
# -16

# %%
# AND Operator:

# %%
12 & 13
# Out:
# 12

# %%
12 & 20
# Out:
# 4

# %%
# OR operator:

# %%
12 | 20
# Out:
# 28

# %%
12 | 13
# Out:
# 13

# %%
# XOR ( if you got same then zero rest is one)

# %%
12 ^ 13
# Out:
# 1

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
25 ^ 30
# Out:
# 7

# %%
# left shift operator:

# %%
12<<1  # you will get one zero at right side of binary number, we gain the bit.
# Out:
# 24

# %%
13<<3  # three zero at right side
# Out:
# 104

# %%
# right shift operator:

# %%
13>>2  # you have to loose two bit from right side, we loss the bit.
# Out:
# 3

# %%
13>>3
# Out:
# 1

# %%
25>>2
# Out:
# 6

# %% [markdown]
# # print():

# %%
num1=10
num2=15
add= num1+num2
print(add)
# Out:
# 25

# %%
num1=10
num2=15
add= num1+num2
print('The addition of {} and {} is ={}'.format (num1,num2,add))
# Out:
# The addition of 10 and 15 is =25

# %%
num1=10  # formatted string
num2=15
add= num1+num2
print(f'The addition of {num1} and {num2} is ={add}')
# Out:
# The addition of 10 and 15 is =25

# %%
print('hello')
print('good afternoon')
# Out:
# hello
# good afternoon

# %%
print('hello',end='----->')
print('good afternoon')
# Out:
# hello----->good afternoon

# %%
print('hello', 'hii', 'how are you?', sep='---->')
# Out:
# hello---->hii---->how are you?

# %%
print('hello', 'hii', 'how are you?', sep='@')
# Out:
# hello@hii@how are you?

# %%
print('hello', 'hii', 'how are you?', sep='#')
# Out:
# hello#hii#how are you?
