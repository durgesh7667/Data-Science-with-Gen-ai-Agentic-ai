# %% [markdown]
# # variable declaration in Python

# %%
data=130

# %%
data
# Out:
# 130

# %%
130=data # you cant write like this.
# Out:
#   Cell In[3], line 1
#     130=data
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1data=23
# Out:
#   Cell In[4], line 1
#     1data=23
#     ^
# SyntaxError: invalid decimal literal

# %%
data1=23

# %%
data1
# Out:
# 23

# %%
_data=23

# %%
data_=23

# %%
d=24
D
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 d=24
# ----> 2 D
#
# NameError: name 'D' is not defined

# %%
d
# Out:
# 24

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
False=23      # you cannot take variable of reserved keyword list
False
# Out:
#   Cell In[15], line 1
#     False=23
#     ^
# SyntaxError: cannot assign to False

# %% [markdown]
# # Datatype in Python

# %%
i=5
i
# Out:
# 5

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
j=2.3
j
# Out:
# 2.3

# %%
type(j)
# Out:
# float

# %%
id(j)
# Out:
# 2469151162704

# %%
4+3
# Out:
# 7

# %%
4+3
4+5
4*5
# Out:
# 20

# %%
print(4+3)  # importance of print function
print(4+5)
print(4*5)
# Out:
# 7
# 9
# 20

# %%
f1=2.3e1
f1
# Out:
# 23.0

# %%
i1=2.4e1
i1
# Out:
# 24.0

# %%
type(f1)
# Out:
# float

# %%
f1=2.3e3
f1
# Out:
# 2300.0

# %%
f1=2.3E3
f1
# Out:
# 2300.0

# %%
f1=2.3d3  # only e/E letter is allowed.
f1
# Out:
#   Cell In[32], line 1
#     f1=2.3d3
#          ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # boolean value

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+True
# Out:
# 2

# %%
True+False
# Out:
# 1

# %%
False+False
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
False%True
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # Complex

# %%
c=3+4j
c
# Out:
# (3+4j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 3.0

# %%
c.imag
# Out:
# 4.0
